# %% [markdown]
# # Import Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/mk-gurucharan/Regression/master/Startups_Data.csv')
data.head()
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
features = ['R&D Spend','Administration','Marketing Spend']
target = 'Profit'
X = data[features]
Y = data[target]

# %% [markdown]
# # Standardize the data

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_transform = ss.fit_transform(X)

# %%
X_train = X[0:39]
X_test = X[39:]
y_train = Y[0:39]
y_test = Y[39:]

# %% [markdown]
# # Find derivatives of loss w.r.t weight and bias.

# %%
#Loss Equation
def loss(y,y_predicted):
    n=len(y)
    s=0
    for i in range(n):
        s+=(y[i]-y_predicted[i])**2
    return (1/n)*s

#code for "wx+b"
def predicted_y(weight,x,intercept):
    y_lst=[]
    for i in range(len(x)):
        y_lst.append(weight@x[i]+intercept) 
    return np.array(y_lst)

#Derivatives of loss w.r.t “weight”
def dldw(x,y,y_predicted):
    s=0
    n=len(y)
    for i in range(n):
        s+=-x[i]*(y[i]-y_predicted[i])
    return (2/n)*s

# Derivatives of loss w.r.t “bias” or “intercept”
def dldb(y,y_predicted):
    n=len(y)
    s=0
    for i in range(len(y)):
        s+=-(y[i]-y_predicted[i])
    return (2/n) * s

def GD(x, y) :
    weight  = np.random.random(x.shape[1])
    epoch = 8000
    intercept = 0
    learning_rate = 0.002
    loss = []

    for i in range(epoch):
        y_predicted = predicted_y(weight_vector,x,intercept)
        weight_vector = weight_vector - learning_rate *dldw(x,y,y_predicted) 
        intercept = intercept - learning_rate * dldb(y,y_predicted)
        lose.append(loss(y,y_predicted))

        plt.plot(np.arrange(1,epoch), loss[1:])
        plt.xlabel("Num Epoch")
        plt.ylabel("Loss")

        return weight, intercept
        #plt.legend()
        #plt.show()

# %% [markdown]
# # Predict

# %%
def prediction(X_inp):
    list = []
    for i in range(len(X_inp)):
        list.append(np.dot(W,X_inp[i]) + B)
    return np.array(list)
